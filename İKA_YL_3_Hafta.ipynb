# %% [markdown]
# İnsan Kaynakları Analitiği Dersi 3 Hafta

# %%
import pandas as pd

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/suacalis/employee_attrition/master/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df2.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 0   41       Yes  ...                       0                     5
# 1   49        No  ...                       1                     7
# 2   37       Yes  ...                       0                     0
# 3   33        No  ...                       3                     0
# 4   27        No  ...                       2                     2
#
# [5 rows x 35 columns]

# %%
df2.tail()
# Out:
#       Age Attrition  ... YearsSinceLastPromotion  YearsWithCurrManager
# 1465   36        No  ...                       0                     3
# 1466   39        No  ...                       1                     7
# 1467   27        No  ...                       0                     3
# 1468   49        No  ...                       0                     8
# 1469   34        No  ...                       1                     2
#
# [5 rows x 35 columns]

# %%
df3=pd.read_csv('https://raw.githubusercontent.com/teuschb/hr_data/master/datasets/MFGEmployees4.csv')

# %%
df3.head()
# Out:
#    EmployeeNumber    Surname GivenName  ... LengthService AbsentHours BusinessUnit
# 0               1  Gutierrez     Molly  ...      6.018478   36.577306       Stores
# 1               2   Hardwick   Stephen  ...      5.532445   30.165072       Stores
# 2               3    Delgado   Chester  ...      4.389973   83.807798       Stores
# 3               4      Simon     Irene  ...      3.081736   70.020165       Stores
# 4               5   Delvalle    Edward  ...      3.619091    0.000000       Stores
#
# [5 rows x 13 columns]

# %%
df4=pd.read_csv('https://raw.githubusercontent.com/teuschb/hr_data/master/datasets/recruitment_evaluation_data.csv')

# %%
df4.head()
# Out:
#    Unnamed: 0  Age  Attrition  ... SalesRating      HireSource Campus
# 0           1   41          1  ...     1.08819  Applied Online    NaN
# 1           2   49          0  ...         NaN             NaN    NaN
# 2           3   37          1  ...         NaN          Campus   Tech
# 3           4   33          0  ...         NaN             NaN    NaN
# 4           5   27          0  ...         NaN        Referral    NaN
#
# [5 rows x 36 columns]

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   Attrition                 1470 non-null   int64
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1470 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1470 non-null   object
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df4.describe()
# Out:
#         Unnamed: 0          Age  ...  YearsWithCurrManager  SalesRating
# count  1470.000000  1470.000000  ...           1470.000000   446.000000
# mean    735.500000    36.923810  ...              4.123129     1.082607
# std     424.496761     9.135373  ...              3.568136     0.710042
# min       1.000000    18.000000  ...              0.000000    -0.710827
# 25%     368.250000    30.000000  ...              2.000000     0.584444
# 50%     735.500000    36.000000  ...              3.000000     1.070143
# 75%    1102.750000    43.000000  ...              7.000000     1.532488
# max    1470.000000    60.000000  ...             17.000000     3.666740
#
# [8 rows x 28 columns]
